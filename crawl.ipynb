# %%
import requests
import os
row = 0 
col = 0
root = "../level20_1915/"
# prefix = "https://wmts100.geo.admin.ch/1.0.0/ch.swisstopo.zeitreihen/default/19311231/2056/20/"
prefix = "https://wmts100.geo.admin.ch/1.0.0/ch.swisstopo.zeitreihen/default/19151231/2056/20/"
# ...level/column/row.png
while True:
    os.mkdir(root + str(col))
    url = prefix + str(col) + "/" + str(row) +".png"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36"}
    html = requests.get(url, headers = headers, allow_redirects=False)
    if html.status_code == 400:
        break
    while True:
        url = prefix + str(col) + "/" + str(row) +".png"
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36"}
        html = requests.get(url, headers = headers, allow_redirects=False)

        if html.status_code == 200:
            file = root + str(col) + "/" + str(row) + ".png"
            with open(file,'wb')as f:
                f.write(html.content)
            print(col, row)
            row += 1
            continue
        else:
            col += 1
            row = 0
            break
# Out:
# 187 0
# 187 1
# 187 2
# 187 3
# 187 4
# 187 5
# 187 6
# 187 7
# 187 8
# 187 9
# 187 10
# 187 11
# 187 12
# 187 13
# 187 14
# 187 15
# 187 16
# 187 17
# 187 18
# 187 19
# 187 20
# 187 21
# 187 22
# 187 23
# 187 24
# 187 25
# 187 26
# 187 27
# 187 28
# 187 29
# 187 30
# 187 31
# 187 32
# 187 33
# 187 34
# 187 35
# 187 36
# 187 37
# 187 38
# 187 39
# 187 40
# 187 41
# 187 42
# 187 43
# 187 44
# 187 45
# 187 46
# 187 47
# 187 48
# 187 49
# 187 50
# 187 51
# 187 52
# 187 53
# 187 54
# 187 55
# 187 56
# 187 57
# 187 58
# 187 59
# 187 60
# 187 61
# 187 62
# 187 63
# 187 64
# 187 65
# 187 66
# 187 67
# 187 68
# 187 69
# 187 70
# 187 71
# 187 72
# 187 73
# 187 74
# 187 75
# 187 76
# 187 77
# 187 78
# 187 79
# 187 80
# 187 81
# 187 82
# 187 83
# 187 84
# 187 85
# 187 86
# 187 87
# 187 88
# 187 89
# 187 90
# 187 91
# 187 92
# 187 93
# 187 94
# 187 95
# 187 96
# 187 97
# 187 98
# 187 99
# 187 100
# 187 101
# 187 102
# 187 103
# 187 104
# 187 105
# 187 106
# 187 107
# 187 108
# 187 109
# 187 110
# ...
