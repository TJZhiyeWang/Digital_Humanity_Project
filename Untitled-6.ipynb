# %%
import requests
import os
row = 0
col = 907
root = "./"
while True:
    os.mkdir(root + str(col))
    url = "https://wmts100.geo.admin.ch/1.0.0/ch.swisstopo.hiks-siegfried/default/current/2056/25/" + str(col) + "/" + str(row) +".png"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36"}
    html = requests.get(url, headers = headers, allow_redirects=False)
    if html.status_code == 400:
        break
    while True:
        url = "https://wmts100.geo.admin.ch/1.0.0/ch.swisstopo.hiks-siegfried/default/current/2056/25/" + str(col) + "/" + str(row) +".png"
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36"}
        html = requests.get(url, headers = headers, allow_redirects=False)

        if html.status_code == 200:
            file = root + str(col) + "/" + str(row) + ".png"
            with open(file,'wb')as f:
                f.write(html.content)
            print(col, row)
            row += 1
            continue
        else:
            col += 1
            row = 0
            break
# Out:
# 907 0
# 907 1
# 907 2
# 907 3
# 907 4
# 907 5
# 907 6
# 907 7
# 907 8
# 907 9
# 907 10
# 907 11
# 907 12
# 907 13
# 907 14
# 907 15
# 907 16
# 907 17
# 907 18
# 907 19
# 907 20
# 907 21
# 907 22
# 907 23
# 907 24
# 907 25
# 907 26
# 907 27
# 907 28
# 907 29
# 907 30
# 907 31
# 907 32
# 907 33
# 907 34
# 907 35
# 907 36
# 907 37
# 907 38
# 907 39
# 907 40
# 907 41
# 907 42
# 907 43
# 907 44
# 907 45
# 907 46
# 907 47
# 907 48
# 907 49
# 907 50
# 907 51
# 907 52
# 907 53
# 907 54
# 907 55
# 907 56
# 907 57
# 907 58
# 907 59
# 907 60
# 907 61
# 907 62
# 907 63
# 907 64
# 907 65
# 907 66
# 907 67
# 907 68
# 907 69
# 907 70
# 907 71
# 907 72
# 907 73
# 907 74
# 907 75
# 907 76
# 907 77
# 907 78
# 907 79
# 907 80
# 907 81
# 907 82
# 907 83
# 907 84
# 907 85
# 907 86
# 907 87
# 907 88
# 907 89
# 907 90
# 907 91
# 907 92
# 907 93
# 907 94
# 907 95
# 907 96
# 907 97
# 907 98
# 907 99
# 907 100
# 907 101
# 907 102
# 907 103
# 907 104
# 907 105
# 907 106
# 907 107
# 907 108
# 907 109
# 907 110
# ...
